# %%
import pandas as pd

# %%
text_file = pd.DataFrame(columns=['text', 'grateful', 'political', 'frustration', 'solution-focused', 'informative or news-focused',
                                  'fearful or panicked', 'blaming', 'seeking help or advice', 'mentions prescribed burn',
                                  'mentions wildfire', 'mentions fire management'])

# %%
text_file
# Out:
# Empty DataFrame
# Columns: [text, grateful, political, frustration, solution-focused, informative or news-focused, fearful or panicked, blaming, seeking help or advice, mentions prescribed burn, mentions wildfire, mentions fire management]
# Index: []

# %%
frustration_text = ['Can someone explain why we STILL haven’t done the prescribed burn we were promised last year? The brush is out of control.',
                    'Tired of watching my tax dollars go to “planning” while the actual burns never happen. Meanwhile, the fire risk just gets worse.',
                    'Prescribed burn canceled AGAIN because of “conditions.” Cool, guess we’ll just wait for the real wildfire then.',
                    'So we’re allowed to choke on wildfire smoke for weeks, but a one-day controlled burn is “too risky”?? Make it make sense.',
                    'Love waking up to smoke and no warning. Is this a prescribed burn or another fire? No communication as usual.',
                    'We begged the county to do a controlled burn behind our neighborhood for years. Now it’s on fire. Unbelievable.',
                    'Why does it take an act of Congress to get a small prescribed burn approved around here? This system is broken',
                    'I support prescribed fire, but maybe don’t do it when the wind’s blowing straight into town? Just a thought.',
                    'The forest is a tinderbox and they’re still “reviewing” the burn permit? What exactly are they waiting for?',
                    'Watched a whole crew prep for a burn, only for it to get canceled with zero notice. So much time wasted.',
                    'Every year they say, “We’re working on prescribed burns.” Every year, we get more fires instead. Tired of the excuses.',
                    'Local tribes literally offered to help manage fire with traditional methods and the state said no?? So frustrating.',
                    'Tried to ask about the smoke today and got bounced between three agencies. No one knows anything. Cool.',
                    'Funny how people complain about prescribed fire smoke but are fine breathing wildfire smoke all summer.',
                    'My research grant depended on that burn going forward. It got canceled for the third time. I’m beyond frustrated.',
                    'Fire season is here and the same fuels that should’ve been burned in spring are still sitting there. Great job, everyone.',
                    'Just once I’d like to see a prescribed burn go through without some last-minute political nonsense shutting it down.',
                    'Imagine being trained, certified, and ready to burn safely, only to get denied because someone at the county “doesn’t feel comfortable".',
                    'If we keep avoiding prescribed burns because of optics, we’re going to keep losing entire forests. Period.',
                    'We finally got a burn window—and then had to stop because neighbors started calling 911 about “wildfire.” Can we PLEASE educate folks?',
                    'Why is everything always so complicated??',
                    'I’m so over it.',
                    'This should NOT be this hard.',
                    'Every time I think it’s sorted, something else goes wrong.',
                    'Just once, can things go smoothly?',
                    'Sick of hitting dead ends.',
                    'I literally don’t have the energy to deal with this again.',
                    'Why does no one ever listen the first time?',
                    'Cool. Another delay. Awesome.',
                    'Getting real tired of “next time.”',
                    'Can we PLEASE stop doing things the hard way?',
                    'This is exhausting.',
                    'I’m trying so hard not to lose it right now.',
                    'It’s like yelling into a void.',
                    'At what point do we admit this system just doesn’t work?',
                    'Nothing ever changes.',
                    'Same story, different day.',
                    'I shouldn’t have to fight this hard to get basic things done.',
                    'Feels like I’m stuck in a loop of pointless setbacks.',
                    'This is beyond frustrating.',
                    'Why is the smoke always worst on the days I actually have plans? Unreal.',
                    'Every time theres a burn, nobody bothers to tell us until the air is already thick.',
                    'Is it really that hard to manage a fire without letting it get out of control?',
                    'Been coughing all day. Can someone please explain how this is “safe”?',
                    'They say its "under control"—cool, then why is my backyard covered in ash again?',
                    'I get prescribed burns are necessary, but come on, give people a heads-up at least.',
                    'Pretty tired of pretending this smoke isn’t affecting my family.',
                    'Another "controlled" fire, another week of feeling like I live in an ashtray.',
                    'If they’re gonna keep lighting fires, the least they could do is communicate better.',
                    'Just once I’d like to go a summer without my lungs feeling like trash. Is that too much to ask?',
                    'Im not anti-burns, I’m anti-being left in the dark.',
                    'Sick of the “unexpected shift in wind” excuse. Happens every single year.',
                    'No updates, no warning, just woke up to orange skies again. Awesome.',
                    'I support the science, but this rollout has been a disaster.',
                    'I asked for info three times and got ghosted. Meanwhile, smoke’s rolling in fast.',
                    'It’s always “part of the plan” until it jumps the line and everyone scrambles.',
                    'Honestly, it just feels like nobody’s learning from past mistakes.',
                    'Love how we all get blamed for wildfires but nothing changes in how theyre managed.',
                    'Burn ban one day, prescribed fire the next. Make it make sense.',
                    'I want to trust the process, but this lack of coordination is exhausting.',
                    'Why does everything have to be so complicated all the time?',
                    'I’m honestly tired of repeating myself over and over.',
                    'Does anyone else feel like they’re running in circles with no end?',
                    'Can someone please explain why nothing ever works out like it’s supposed to?',
                    'I don’t even know what to do anymore. Just fed up.',
                    'Trying so hard but feeling like I’m just hitting a wall.',
                    'Is it really too much to ask for a little break?',
                    'I swear, some days it feels like the universe is just messing with me.',
                    'So done with all the back and forth and no progress.',
                    'Why is it so hard to get a straight answer?',
                    'Im trying to stay positive but this is honestly getting exhausting.',
                    'Feel like I’m stuck in this loop and can’t find a way out.',
                    'Seriously, how does this keep happening?',
                    'Not sure if I should laugh or cry at this point.',
                    'Wish people would just communicate better already.',
                    'Im all for patience, but this is testing me.',
                    'Just when I think its going to get better, nope.',
                    'Why is everyone so difficult today?',
                    'Feeling like Im the only one who cares sometimes.',
                    'Honestly, some days I wonder if its even worth it.'
]
political_text = ['Tired of politicians talking about “forest health” without backing actual burn programs.',
                  'How are we still arguing about prescribed burns when we’re choking on wildfire smoke every summer?',
                  'More meetings, more task forces… still no fire on the ground. We need less talk, more action.',
                  'Every year we watch preventable wildfires tear through the same areas. Why is policy always reactive?',
                  'It’s wild how political optics keep outweighing decades of fire science.',
                  'State and federal agencies need to stop blaming each other and coordinate before the next fire season hits.',
                  'Glad to see our local officials finally investing in prescribed burn training. It’s a good step.',
                  'Appreciating the collaboration between tribes and state fire crews this season — long overdue but moving in the right direction.',
                  'Grateful that fire management is becoming more of a bipartisan issue. We need solutions, not sides.',
                  'Big thanks to the folks behind the scenes who pushed for burn funding in this year’s budget.',
                  'Encouraged to see elected leaders taking time to learn from fire ecologists — science should guide policy.',
                  'Prescribed burns don’t get headlines, but they save lives. Glad to see more political support this year.',
                  'There’s definitely more attention on prescribed burns lately — will be interesting to see how policy adapts.',
                  'Seems like more communities are pushing local officials to take proactive fire steps. Could be a shift happening.',
                  'Both political sides seem to agree fire management is important, but approaches vary widely.',
                  'The policy around fire is complex — balancing smoke, ecology, safety, and public opinion is no easy task.',
                  'Fire management is becoming a regular part of climate policy discussions. That’s new.',
                  'Saw that the new legislation includes incentives for prescribed fire — curious to see how that plays out in practice.',
                  'Public pressure really seems to influence whether burns happen. Politics and perception go hand in hand here.',
                  'It’s clear that prescribed fire isn’t just a science issue — it’s deeply political and tied to public trust.',
                  'Feels like every election is just picking the lesser of two evils.',
                  'How do we have record budgets and still no progress on basic infrastructure?',
                  'So tired of the performative outrage. Can we focus on actual solutions for once?',
                  'It’s amazing how fast they pass bills for corporations, but drag their feet on anything for regular people.',
                  'Every politician promises change, and then nothing changes.',
                  'Why is transparency still optional in government?',
                  'Watching lawmakers argue while people struggle is honestly infuriating.',
                  'Appreciating that my rep actually responds to emails and town halls. That matters.',
                  'Shoutout to the people working behind the scenes on policy — it’s not always visible but it adds up.',
                  'Not perfect, but progress is progress. Grateful for leaders who listen.',
                  'Seeing bipartisan support on this issue is honestly refreshing.',
                  'Proud to live somewhere that encourages civic engagement.',
                  'There are good people in government trying their best — we just don’t hear about them enough.',
                  'Policy change is slow, but sometimes that’s how systems are designed.',
                  'Interesting how public opinion can shift so quickly depending on media framing.',
                  'The election results weren’t surprising, but the voter turnout trends definitely were.',
                  'It’s clear that trust in institutions is declining — the question is, how do we rebuild it?',
                  'This issue is getting traction on both sides, which could mean a real shift is coming.',
                  'A lot of younger voters are starting to get more involved — curious to see how that plays out long-term.',
                  'The disconnect between local and national politics keeps growing. Might be time to pay closer attention to city councils.',
                  'Funny how these "fire management" plans always come out right before election season...',
                  'If only decisions around prescribed burns were as transparent as campaign promises.',
                  'Seems like wildfire policies change with every new administration—when will we get consistency?',
                  'The politics behind who controls the burns are almost as hot as the fires themselves.',
                  'Lots of talk about safety, but who really benefits from these fire management programs?',
                  'Im all for protecting the environment, but is this just another way to control land use?',
                  'Prescribed burns sound good on paper, but what’s the real agenda behind them?',
                  'It’s good to see more funding going toward wildfire prevention this year—hope it actually makes a difference.',
                  'Prescribed burns aren’t perfect, but at least they show officials are trying something proactive.',
                  'Politics aside, managing forests better is something everyone can get behind.',
                  'I appreciate when leaders listen to scientists about fire risks rather than just politics.',
                  'Not sure if all these new fire policies will help, but it’s better than doing nothing.',
                  'Watching how different states handle fire management is like a political experiment.',
                  'It’s encouraging to see bipartisan support for better wildfire management programs.',
                  'Sometimes I wonder if politics slows down progress on fire safety, but then I see small wins.',
                  'I’m cautiously optimistic about the new fire management initiatives coming from the city.',
                  'Fire safety should be a priority no matter who’s in office—let’s hope it stays that way.',
                  'Some of the policies seem slow to roll out, but better late than never.',
                  'Politics can complicate things, but at least fire management is finally part of the conversation.',
                  'I’m hopeful that with more funding and awareness, wildfire seasons will improve.',
                  'Seeing politicians actually visit fire-affected areas gives me a bit of hope.',
                  'Politics always feels like a rollercoaster—some days you’re up, some days you’re just hanging on.',
                  'It’s refreshing when politicians actually follow through on their promises.',
                  'Sometimes I wonder if all the drama is just distraction from the real issues.',
                  'I’m cautiously optimistic about the new policies being proposed this year.',
                  'Feels like progress is slower than it should be, but at least something’s moving.',
                  'Not sure who to trust anymore—everyone seems to have an agenda.',
                  'It’s great to see communities coming together regardless of political differences.',
                  'Sometimes politics feels like a game where the people lose more than they win.',
                  'I appreciate when leaders prioritize facts over rhetoric.',
                  'It’s hard to tell if any of this will actually change things in the long run.',
                  'There are moments when politics surprises me—in a good way.',
                  'It’s frustrating how often meaningful discussions get sidetracked.',
                  'I’m hopeful that more transparency will lead to better outcomes.',
                  'Politics isn’t perfect, but it’s what we have to work with.',
                  'Seeing bipartisan efforts gives me some faith in the system.',
                  'Sometimes it feels like politicians care more about power than people.',
                  'I’m tired of the constant back-and-forth, but I’m not giving up.',
                  'It’s nice to see fresh faces bringing new ideas to the table.',
                  'Politics can be messy, but change usually comes from the mess.',
                  'At the end of the day, it’s about finding common ground—even if it’s hard.',
]

# %%
grateful_text = ['Huge thanks to the fire crews doing prescribed burns today — that work makes a real difference.',
                 'Appreciating all the planning that goes into keeping these burns safe and effective.',
                 'Grateful for the folks doing the hard work so we don’t have to breathe wildfire smoke all summer.',
                 'Honestly so thankful that our region supports proactive fire management. It’s paying off.',
                 'Shoutout to the teams educating the public about prescribed fire — communication is key.',
                 'Glad to see science-backed fire strategies getting the attention they deserve.',
                 'Respect to everyone who’s out there managing land the right way — you’re protecting more than trees.',
                 'Appreciate the transparency around this week’s prescribed burn schedule. Makes such a difference for the community.',
                 'Grateful our county prioritized fire mitigation this year — it shows real leadership.',
                 'Big thanks to the local tribe for sharing knowledge and leading prescribed burn efforts. That’s real stewardship.',
                 'Feeling lucky to live in a place that values fire ecology and prevention.',
                 'These burns aren’t just smoke — they’re protection, regeneration, and care. Thanks to those making it happen.',
                 'Appreciate all the coordination between agencies this season. It’s making things safer for everyone.',
                 'So thankful for the burn boss and team who took time to talk with residents beforehand. That matters.',
                 'Every acre treated is a step toward a safer future. Deep gratitude to those doing the work.',
                 'Thank you to the crews who spend months prepping for a burn that takes hours. That’s commitment.',
                 'It’s reassuring to see fire management being treated as a long-term strategy, not just emergency response.',
                 'Feeling hopeful after seeing how many young people are getting trained in prescribed fire.',
                 'Grateful for the public meetings and clear communication. Builds trust around fire work.',
                 'Thanks to all who are working with nature, not against it, when it comes to fire.',
                 'Feeling really thankful for the little things today. They add up.',
                 'Appreciate the people who show up even when they don’t have to.',
                 'Grateful for progress, no matter how slow it feels sometimes.',
                 'Shoutout to everyone quietly doing the work that keeps things running.',
                 'Thank you to the friends who check in just because. That means more than you know.',
                 'Some days you just have to stop and appreciate how far you’ve come.',
                 'Feeling lucky to be surrounded by people who care.',
                 'Appreciate the calm days. They’re easy to overlook, but they matter too.',
                 'Grateful for honest conversations. Even the hard ones.',
                 'Thanks to those who take the time to listen — truly listen.',
                 'Today I’m just thankful for fresh air, good coffee, and a little peace.',
                 'Big thanks to the people doing the unglamorous jobs. You’re seen.',
                 'Appreciate the folks who bring good energy into a room. That’s a gift.',
                 'Grateful for learning moments — even the messy ones.',
                 'Some support doesn’t need to be loud to be powerful. Thank you.',
                 'Thankful for second chances and small wins.',
                 'Appreciate every person who shows patience when things are tough.',
                 'Grateful for anyone who’s doing their best, even if it’s not perfect.',
                 'Thanks for the kindness — unexpected and very much needed.',
                 'Today I’m just thankful for stability. That’s not guaranteed, and I don’t take it for granted.',
                 'Honestly, thankful for anyone out there working to keep these fires under control.',
                 'Appreciate the teams doing prescribed burns even if it means a smoky week.',
                 'Grateful we’ve got some plans in place to handle wildfire season this year.',
                 'Big thanks to those managing the forests—hope it helps reduce the risk.',
                 'It’s nice to see some proactive fire management finally happening around here.',
                 'Glad the community is coming together around these fire safety efforts.',
                 'Can’t thank the crews enough for working hard in tough conditions.',
                 'Thankful for science-backed approaches, even if the smoke isn’t fun.',
                 'Grateful for small steps toward better wildfire prevention.',
                 'Appreciate the info shared about prescribed burns, helps me feel prepared.',
                 'Thanks to everyone pushing for smarter fire management policies.',
                 'Feeling lucky that some fires are controlled before they get worse.',
                 'Grateful for the updates, even if they mean staying indoors today.',
                 'Thank you to the experts trying to balance safety with nature’s needs.',
                 'Appreciate that fire management is finally getting some attention.',
                 'Grateful to live in a place where we’re at least trying to tackle wildfire risks.',
                 'Thanks to the volunteers helping with fire prevention in our neighborhood.',
                 'It’s reassuring to know people are working behind the scenes on this.',
                 'Thankful for the efforts, even if I wish things moved faster sometimes.',
                 'Big shoutout to everyone involved in keeping our communities safer from fires.',
                 'Really appreciate everyone who’s been there through the tough times.',
                 'Grateful for the little things that keep me going these days.',
                 'Thankful for the support, even when things aren’t perfect.',
                 'Appreciate the efforts people make, no matter how small.',
                 'Feeling grateful for moments of calm in a crazy world.',
                 'Thanks to those who try, even if it doesn’t always work out.',
                 'I’m thankful for the chances I get to start fresh.',
                 'Appreciate the kindness that pops up when you least expect it.',
                 'Grateful for the lessons, even the hard ones.',
                 'Thank you for those who stick around when it matters most.',
                 'Feeling lucky for the people who keep showing up.',
                 'Appreciate every bit of progress, no matter how slow.',
                 'Grateful for the breaks that help me breathe.',
                 'Thankful for the voices that speak up, even when it’s tough.',
                 'Appreciate the effort it takes to keep moving forward.',
                 'I’m grateful for the unexpected moments of joy.',
                 'Thank you for the patience and understanding along the way.',
                 'Feeling thankful for chances to learn and grow.',
                 'Appreciate the times people come together, no matter the reason.',
                 'Grateful for today and whatever it brings.'
]

solution_focused_text = ['Instead of waiting for the next big wildfire, we need to expand prescribed burn programs now.',
                         'We should be funding year-round fire crews, not just reacting during fire season.',
                         'More partnerships with Indigenous fire practitioners could seriously improve our land management.',
                         'It’s time to treat fire like a tool, not just a threat. Let’s invest in education and training.',
                         'If we want fewer catastrophic wildfires, we need to support more controlled burns and fuel reduction.',
                         'Public outreach is key — people need to know why prescribed fire is part of the solution.',
                         'Let’s make it easier for private landowners to safely conduct burns with expert guidance.',
                         'We need policies that encourage proactive fire management instead of just emergency responses.',
                         'Incorporating cultural burning practices isn’t just respectful — it’s effective.',
                         'Let’s push for better smoke planning so burns can happen safely without harming communities.',
                         'Investing in local fire crews also builds climate resilience and job opportunities.',
                         'We should integrate prescribed fire planning into broader climate adaptation efforts.',
                         'There’s no one-size-fits-all solution, but fire science and traditional knowledge together are powerful.',
                         'Time to shift public perception: not all fire is bad fire.',
                         'Let’s allocate more resources to fire weather monitoring to help time burns more effectively.',
                         'We need more state-level support so local agencies aren’t carrying the burden alone.',
                         'Creating burn-ready landscapes today could save millions in suppression costs tomorrow.',
                         'More fire ecology in schools = more understanding and fewer misconceptions.',
                         'Let’s support pilot programs that allow for safe, low-risk winter burns in key areas.',
                         'If the West wants to reduce megafires, we need to normalize fire as part of healthy land care.',
                         'Complaining’s easy — building solutions is where the real work (and change) happens.',
                         'What if we focused less on who’s to blame and more on what we can fix today?',
                         'Change doesn’t have to be massive to matter — small steps still move things forward.',
                         'Let’s stop waiting for someone else to solve it and start where we can.',
                         'We won’t fix everything overnight, but we can start by listening better.',
                         'Transparency, empathy, and action — we need more of all three right now.',
                         'If we want different outcomes, we need different conversations.',
                         'Real progress comes from people willing to roll up their sleeves, not just talk.',
                         'Let’s ask: what’s working, and how can we build on that?',
                         'It’s not about being perfect — it’s about being willing to try something new.',
                         'Instead of just pointing out the flaws, let’s pitch some fixes too.',
                         'Solutions aren’t always flashy. Sometimes they’re quiet, local, and effective.',
                         'What if the next great idea comes from someone who’s never been heard before? Let’s listen.',
                         'Let’s start measuring success by who’s helped, not who’s right.',
                         'If something’s broken, we don’t need to tear it all down — maybe just rebuild smarter.',
                         'Progress doesn’t mean rushing — it means moving with purpose.',
                         'Compromise isn’t weakness. It’s a strategy for getting things done.',
                         'Imagine how far we’d get if we focused on shared goals instead of constant division.',
                         'Solutions take time, but excuses take energy. Let’s use our energy better.',
                         'We don’t have to agree on everything to make meaningful change together.',
                         'Maybe if we invest more in prescribed burns, we can finally get ahead of wildfire season.',
                         'It feels like smarter fire management could make a real difference this year.',
                         'Wondering if better community education around fire risks would help reduce damage.',
                         'Could controlled burns be the key to safer forests? I’m starting to think so.',
                         'I’m hopeful that new tech will improve wildfire detection and response times.',
                         'Maybe collaboration between agencies is what we need to tackle these fires.',
                         'It’d be great if we could find a balance between nature and safety with fire management.',
                         'Prescribed burns might be controversial, but they seem like a practical step forward.',
                         'What if more funding went toward prevention rather than just fighting fires?',
                         'I’m curious if we could use data better to predict wildfire risks before they spread.',
                         'Maybe local communities should have more say in how fire management happens.',
                         'Investing in fire-resistant infrastructure might be a smart move going forward.',
                         'It seems like there are some promising solutions out there, just need more support.',
                         'Could better communication help reduce the risks of prescribed burns?',
                         'I think long-term planning around fire management is finally gaining traction.',
                         'Would more public awareness campaigns help people prepare for wildfire season?',
                         'It’s clear we need new approaches—maybe prescribed burns are part of the answer.',
                         'If agencies worked together more, maybe wildfire impacts could be lessened.',
                         'Wondering if we’re close to finding effective fire management strategies that stick.',
                         'Hopeful that combining science and policy can lead to better fire safety solutions.'
                         'Maybe if we all work together, things can actually start to improve.',
                         'Feels like there’s potential in trying new approaches, even if they’re untested.',
                         'Wondering if better communication could help resolve some ongoing problems.',
                         'Could small changes make a bigger difference than we expect?',
                         'I’m hopeful that focusing on solutions instead of blame will get us somewhere.',
                         'Maybe the key is more collaboration and less arguing.',
                         'It’d be great if we could find common ground and move forward.',
                         'Sometimes the simplest fixes are the ones that work best.',
                         'What if we tried listening more before jumping to conclusions?',
                         'I think we’re on the right track, but there’s still work to be done.',
                         'Could more awareness and education be the missing pieces?',
                         'Hopeful that innovation will lead to new ways of solving old problems.',
                         'It’s encouraging to see people coming up with fresh ideas lately.',
                         'Maybe the solutions are out there—we just need to find them.',
                         'Feels like this is a moment where positive change is possible.',
                         'If we focus on what works instead of what doesn’t, progress seems likely.',
                         'Could more patience and understanding lead to better outcomes?',
                         'I’m optimistic that by working together, we can figure this out.',
                         'Sometimes the best solutions come from unexpected places.',
                         'It’s about finding what moves us forward, even if it’s just a small step.'
]

# %%
informative_news_focused_text = ['A prescribed burn is scheduled for tomorrow in the lower valley region — expect light smoke through mid-afternoon.',
                                    'Fire crews successfully treated 250 acres with prescribed fire this week to reduce fuel load ahead of summer.',
                                    'New research shows that areas treated with prescribed burns had significantly lower wildfire severity.',
                                    'The Forest Service is increasing its use of cultural burning practices in collaboration with tribal partners.',
                                    'Smoke from today’s prescribed burn may be visible near Highway 9, but officials say conditions are controlled.',
                                    'A new state bill proposes increased funding for year-round prescribed fire crews and training programs.',
                                    'This week’s fire risk remains low, allowing for safe execution of several controlled burns across the county.',
                                    'Prescribed burns have resumed following last week’s storm system that brought favorable weather conditions.',
                                    'Experts say using prescribed fire in early spring can help prevent catastrophic blazes later in the season.',
                                    'Public input is open on the updated fire management plan, which includes more community-based burn units.',
                                    'The prescribed fire planned for Thursday will help reduce invasive species and improve wildlife habitat.',
                                    'A new mapping tool now shows active and completed prescribed burns across the state.',
                                    'According to CAL FIRE, prescribed burns have already treated over 20,000 acres this year — up 30% from last year.',
                                    'A temporary health advisory has been issued due to smoke from multiple planned burns in the region.',
                                    'Wildfire recovery teams are studying how past prescribed burns influenced the spread of recent fires.',
                                    'The new fire management initiative includes funding for local burn bosses and community outreach.',
                                    'Prescribed fire season has officially begun, with multiple agencies coordinating burn schedules statewide.',
                                    'Local fire officials emphasize that prescribed burns are planned months in advance under strict conditions.',
                                    'A new fire ecology program is teaching students the benefits of prescribed fire as a land management tool.',
                                    'The recent prescribed fire near Pine Ridge successfully restored native grasslands and reduced fire risk.',
                                    'The city council approved the budget proposal last night with a 6–1 vote.',
                                    'Gas prices are expected to drop slightly this weekend, according to AAA.',
                                    'A new study shows that remote work can increase productivity by up to 13%.',
                                    'Early voting for the local election begins next Monday across all precincts.',
                                    'The FDA just approved a new medication for seasonal allergies.',
                                    'Local transit will operate on a reduced schedule this Friday due to maintenance.',
                                    'Scientists have discovered a new species of orchid in the Amazon rainforest.',
                                    'Unemployment rates remained steady this month, holding at 4.2% nationally.',
                                    'The annual music and arts festival kicks off this weekend with over 100 performers.',
                                    'Police are investigating a string of car break-ins reported downtown last night.',
                                    'The health department is offering free flu shots at all clinics this week.',
                                    'A major software update is rolling out to devices starting today.',
                                    'Construction on the new library branch is ahead of schedule and under budget.',
                                    'Meteorologists are tracking a potential storm system expected to arrive late Thursday.',
                                    'Public schools will be closed Monday in observance of the holiday.',
                                    'The National Park Service is waiving entry fees this Saturday for all visitors.',
                                    'A new local ordinance bans single-use plastic bags starting January 1st.',
                                    'A record number of small businesses have opened in the district this quarter.',
                                    'City officials announced plans for a new bike lane expansion project this fall.',
                                    'A community meeting will be held Wednesday to discuss the proposed zoning changes.',
                                    'Officials report increased prescribed burn activities in the northern forests this week.'
                                    'New data suggests wildfire risks may be shifting due to recent weather patterns.',
                                    'Fire management teams have been conducting controlled burns ahead of peak season.',
                                    'Recent satellite images show smoke plumes near several managed fire zones.',
                                    'Emergency services are on alert as wildfire season officially begins.',
                                    'Authorities remind residents about upcoming prescribed burn schedules.',
                                    'Local agencies are coordinating fire prevention efforts across multiple counties.',
                                    'Weather forecasts predict higher temperatures, raising wildfire concerns.',
                                    'Updates indicate prescribed burns have reduced fuel loads in several key areas.',
                                    'Fire crews have successfully contained recent wildfires with new tactics.',
                                    'State officials emphasize the importance of fire-safe landscaping this year.',
                                    'New policies encourage the use of controlled burns for ecosystem health.',
                                    'Monitoring systems are being upgraded to improve wildfire detection.',
                                    'Researchers publish findings on the benefits of prescribed fire in forest management.',
                                    'Community meetings scheduled to discuss upcoming fire management plans.',
                                    'Officials confirm no new wildfire outbreaks reported in the last 48 hours.',
                                    'Smoke advisories issued for areas near active prescribed burns.',
                                    'Fire prevention tips shared ahead of the high-risk summer months.',
                                    'Collaboration between agencies aims to enhance wildfire response strategies.',
                                    'Recent reports highlight the balance between fire management and environmental concerns.',
                                    'Hearing more people are moving out of cities lately. Wonder what’s driving the trend.',
                                    'Seems like more schools are shifting their policies again — hard to keep up.',
                                    'Gas prices just spiked again in some areas. No word yet on how long it’ll last.',
                                    'There’s been a lot of chatter around changes to work-from-home policies lately.',
                                    'Looks like another round of layoffs is hitting the tech industry this week.',
                                    'More folks are starting to talk about the mental health impacts of constant notifications.',
                                    'Can’t ignore how much talk there is about AI tools in classrooms lately.',
                                    'The new transit expansion just opened, but reviews so far seem mixed.',
                                    'Noticing more posts about quiet quitting again. Guess it’s not going away yet.',
                                    'Some cities are testing guaranteed income programs. Curious how that’s going to play out.',
                                    'Apparently there’s a big shift happening in how food delivery apps pay their drivers.',
                                    'More regions are experiencing unusual weather patterns this month.',
                                    'There’s been a steady rise in solar panel installations, especially in rural areas.',
                                    'Another major brand just announced it’s going fully digital. Sign of the times?',
                                    'Local communities are starting to set up their own mutual aid networks again.',
                                    'Seems like fewer people are watching cable TV these days — streaming keeps climbing.',
                                    'Some cities are banning short-term rentals again. Definitely sparking debate.',
                                    'A lot of buzz around universal basic income lately — not just fringe talk anymore.',
                                    'There’s a growing push to rethink how we measure productivity.',
                                    'More places are experimenting with 4-day workweeks. Results so far? Mixed.'
                                
]

fearful_or_panicked_text = ['Why does it smell like smoke again? Is there a fire nearby?? No warning, nothing??',
                            'I just saw flames behind the ridge — is this a controlled burn or are we in danger?!',
                            'The sky turned orange in minutes. This can’t be normal. What is going on??',
                            'We didn’t get any notice about this burn and now my whole neighborhood is filled with smoke. This is terrifying.',
                            'I have asthma and no one told us there would be smoke today. This feels reckless and unsafe.',
                            'It’s too hot and dry right now — why are they even doing prescribed burns in these conditions??',
                            'Our town is still recovering from the last fire and they’re lighting another one? I’m honestly scared.',
                            'The smoke is so thick I can’t see across the street. Are we supposed to just sit here and hope it’s fine??',
                            'Every time I hear about a ‘controlled burn,’ I panic. That’s how the last fire started!',
                            'Something’s not right… I have a really bad feeling about this.',
                            'Why is no one talking about this?! This is getting out of control.',
                            'I’m seriously freaking out right now. What are we supposed to do??',
                            'My heart is racing. I don’t feel safe anymore.',
                            'Every update just makes me more anxious. This is terrifying.',
                            'How are we just expected to sit here and act like everything’s normal?!',
                            'This is way bigger than people realize. We’re not prepared for this.',
                            'Please tell me someone else is seeing this — I’m not overreacting, right??',
                            'It’s all happening so fast. I don’t even know what to think anymore.',
                            'Woke up to smoke again. Not sure if it’s another burn or something worse.',
                            'Getting alerts on my phone but no ones saying if we need to evacuate yet.',
                            'That smell is back and it’s stronger than yesterday. Anyone else noticing it?',
                            'Honestly not sure if this fire is “under control” like they keep saying.',
                            'Sky looks yellow and hazy... should I be worried or is this still part of the plan?',
                            'Neighbors are packing up just in case — makes you wonder if we should too.',
                            'I know they said its a prescribed burn, but it feels like it’s getting too close.',
                            'No official updates in hours. Kinda freaking out watching the flames from my porch.',
                            'Trying not to panic but it’s hard when the smoke keeps getting thicker and no one explains anything.',
                            'Anyone else feeling super uneasy about how quiet things have been lately?',
                            'Not gonna lie, that email subject line gave me a mini heart attack.',
                            'I keep refreshing the app like something bad’s about to happen.',
                            'Trying not to spiral but everything just feels off today.',
                            'Is it just me or does this whole situation seem like it’s about to go sideways?',
                            'Kinda freaking out a little but maybe I’m just overthinking it.',
                            'I hate when people say “we need to talk” and then don’t follow up for hours.',
                            'Honestly thought things would feel better by now, but they don’t.',
                            'Wish I could sleep but my brain clearly has other plans tonight.'
]

# %%
blaming_text = ['This fire could’ve been prevented if they had managed the land properly.',
                'Whose bright idea was it to light a prescribed burn during high winds?!',
                'Every year it’s the same mess — no accountability, just smoke and damage.',
                'They knew the risks and did it anyway. Now look at the outcome.',
                'The agencies in charge clearly aren’t listening to the communities affected.',
                'All this damage because someone thought they knew better than the weather report.',
                'It’s always reactive, never proactive. They wait until it’s too late.',
                'Years of mismanagement and now we’re the ones paying the price.',
                'They said it was “controlled.” What part of this disaster looks controlled??',
                'It’s negligence, plain and simple. And no one’s taking responsibility.',
                'They let everything burn before they even consider alternative approaches.',
                'Who approved this? They should be held accountable for the damage.',
                'Stop blaming climate — this is human error and poor leadership.',
                'If they’d done proper maintenance, we wouldn’t be here right now.',
                'How many more homes have to be lost before they admit they messed up?',
                'The communication has been terrible. People had no warning at all.',
                'This isn’t nature’s fault — it’s bad planning by people in power.',
                'They’ve ignored Indigenous fire knowledge for decades. This is what happens.',
                'Their “management” has led directly to disaster. Again.',
                'It’s hard to trust any official statements when they keep making the same mistakes.',
                'This is what happens when no one takes responsibility from the start.',
                'They had one job and still managed to screw it up.',
                'I warned everyone this would happen, but no one listened.',
                'It’s not a “surprise” — it’s pure negligence.',
                'The people in charge dropped the ball. Again.',
                'All this chaos because someone didn’t plan ahead.',
                'I’m tired of cleaning up other people’s messes.',
                'If they had just followed through, we wouldn’t be in this situation.',
                'This is entirely their fault. There’s no excuse.',
                'Poor decisions lead to poor outcomes — not rocket science.',
                'They ignored the warning signs and now everyone’s suffering.',
                'How hard is it to do the right thing the first time?',
                'No accountability, just finger-pointing and deflection.',
                'Don’t blame the system — blame the people running it.',
                'It’s always someone else’s fault until everything falls apart.',
                'They knew the risks and chose to look the other way.',
                'This isn’t a mistake — it’s a pattern.',
                'The writing was on the wall, and they still didn’t act.',
                'Everyone saw this coming except the ones who were supposed to prevent it.',
                'We’re left dealing with the consequences of their bad decisions.',
                'Funny how this keeps happening every year and no one seems to change anything.',
                'Youd think by now there’d be a better system in place.',
                'Not sure if it was poor planning or bad luck, but here we are again.',
                'Hard to believe this was all “under control” a few hours ago.',
                'Every time they say “routine burn,” it somehow ends up like this.',
                'Wish they’d actually listen to the people who live here.',
                'It’s almost like no one’s learning from past mistakes.',
                'The smoke was supposed to clear by now. Someone misjudged that one.',
                'Feels like the decisions are being made by people who don’t even live near this.',
                'You can’t just call it “necessary” and then ignore the consequences.',
                'This is what happens when budgets get slashed year after year.',
                'They always say they’re being transparent, but updates are vague at best.',
                'If this is the “best practice,” then we’re in trouble.',
                'A little more communication up front might’ve avoided all this confusion.',
                'Still can’t believe they thought this timing made sense.',
                'People warned them this could happen. Guess that didn’t matter.',
                'I know it’s complicated, but someone dropped the ball here.',
                'The fireline wasn’t supposed to cross that ridge. So what went wrong?',
                'Once again, it’s the communities left to deal with the fallout.',
                'Is it just me, or does this keep happening when certain crews are in charge?',
                'Some decisions really come back to bite us, huh?',
                'Hard not to wonder how we got here… again.',
                'Feels like this could’ve been avoided with a little foresight.',
                'It’s wild how people act surprised like they didn’t help cause this.',
                'Not pointing fingers, but this isn’t just “bad luck.”',
                'You can’t keep doing the same thing and expect different results.',
                'We were warned. Can’t say we didn’t see this coming.',
                'Maybe if people actually paid attention the first time, we wouldn’t be here.',
                'Funny how the ones in charge are suddenly quiet.',
                'I guess accountability isn’t part of the plan.',
                'The silence is loud from those who helped make this mess.',
                'It’s easy to shrug now, but where was all that urgency earlier?',
                'Why does it always fall on the rest of us to clean it up?',
                'You can’t just say “we did our best” when this is the outcome.',
                'Would’ve been nice if someone had actually stepped in before it got to this.',
                'Some folks really made it worse by doing nothing.',
                'Decisions were made. Let’s not pretend they didn’t have consequences.',
                'Not naming names, but some people clearly weren’t thinking ahead.',
                'If only someone had considered the impact before pushing this through.',
                'Feels like we’re paying the price for someone else’s shortcuts.'
]

seeking_help_or_advice_text = ['Anyone know how prescribed burns actually help with wildfire prevention? Kinda confused here.',
                               'Planned burn happening near my cabin this week... should I be worried or just chill?',
                               'Saw smoke today—how do I tell if it’s a prescribed burn or something worse?',
                               'First time dealing with this—what should I do to prep my property before a burn nearby?',
                               'Moved here recently—how do y’all tell the difference between a wildfire and a controlled burn?',
                               'Airs been super smoky all day. Is it safe to go out during these burns? Asthma’s acting up 😷',
                               'Low-key nervous... can these prescribed fires ever get outta control?',
                               'Where do I even find updates on fire management stuff in my area? County site is a mess.',
                               'Fire season’s coming—any tips for keeping livestock safe? First time dealing with this.',
                               'Anyone hear if they’re doing a burn near Hwy 12 this week? Trying to plan a trip.',
                               'My parents live near a scheduled burn zone and they’re elderly—should I move them temporarily?',
                               'How long does the smoke hang around after one of these prescribed burns?',
                               'Is there a hotline or something for questions about local burns? I’ve got so many rn.',
                               'We’ve got asthma in the fam—how do you know which days are safe to be outside during burn season?',
                               'Trying to get a burn permit for some brush—who do I even call for that?',
                               'Is it normal for prescribed fires to be set this close to homes? Kinda freaking out.',
                               'What’s in your go-bag for fire season? Just in case one of these burns goes sideways.',
                               'Are there any workshops or resources for learning about fire management for private landowners?',
                               'Can someone explain how to read these fire risk maps the fire dept posted? I’m lost lol.',
                               'Worried about fire danger near our cabin—who do I talk to about mitigation plans or support?',
                               'Anyone else dealing with this? Not sure what to do next—open to any advice.',
                               'Kinda stuck and could really use some help. Has anyone gone through something similar?',
                               'Not trying to be dramatic but I’m overwhelmed. What would you do in this situation?',
                               'Can someone explain this to me like I’m five? I’m so lost lol.',
                               'Looking for some guidance here—any tips are appreciated 🙏',
                               'Totally new to this and I have no idea what I’m doing. Help??',
                               'Need a second opinion: am I overthinking this or is it actually a big deal?',
                               'Has anyone been through this before? Would love to hear how you handled it.',
                               'Feeling stuck and unsure who to ask. Reddit, do your thing.',
                               'Quick question—what would you do if you were in my shoes?',
                               'Not sure if I’m handling this right. Advice welcome.',
                               'Is this normal? Trying to figure out what the next step is here.',
                               'Need help figuring this out—DMs open if you’ve got time to talk.',
                               'Reddit, help me out: what should I do about this?',
                               'Kinda lost right now, tbh. Has anyone dealt with something like this?',
                               'I feel like I’ve tried everything. Anyone have a fresh perspective?',
                               'SOS—what would you do if this happened to you?',
                               'Can’t be the only one who’s struggled with this, right? What worked for you?',
                               'Looking for honest opinions here—please be real with me.',
                               'I’m not even sure what to ask, I just know I need help figuring this out.',
                               'Anyone else confused about what “low-intensity” fire actually means?',
                               'Trying to understand if this smoke is from a planned burn or not. Any tools for checking?',
                               'Kinda torn on whether we should be concerned about this—any local folks know more?',
                               'Curious how people nearby usually prepare for these burns. First time experiencing one.',
                               'Is there a reason they burn this close to neighborhoods? Just trying to wrap my head around it.',
                               'Been seeing helicopters all morning—is this normal for this time of year?',
                               'Not sure if staying indoors is enough when the air smells like this. What do y’all do?',
                               'This might be a dumb question, but… who exactly manages these fires?',
                               'Genuinely unsure if I should be worried or not—anyone been through this before?',
                               'Does anyone know if pets are affected by smoke from a prescribed fire?',
                               'First time living in a fire-prone area—what should I be paying attention to right now?',
                               'How do people tell when a controlled burn gets out of control?',
                               'This might sound paranoid, but when should we consider evacuating just in case?',
                               'Reading up on prescribed burns and I still don’t fully get why they’re done in summer—any good resources?',
                               'Is it normal for burns to last multiple days? Feeling a little uneasy.',
                               'The alerts are kind of vague—is there a better way to stay informed?',
                               'Anyone know how long the smoke usually lingers after these things?',
                               'What do you all do to protect your lungs during this stuff?',
                               'If the fire crews say “under control,” should we just trust that?',
                               'Any longtime locals have advice for dealing with this season in general?',
                               'Kinda feeling stuck right now, not sure what the next move is supposed to be.',
                               'Anyone else been through something like this before? Just wondering how it played out for you.',
                               'Not really sure if I’m overthinking or if this is actually a big deal.',
                               'Trying to figure this out, but everything online says something different.',
                               'What do people usually do in situations like this?',
                               'Still weighing options. Would love to hear how others handled it, if you’ve been there.',
                               'Every time I think I’ve made a decision, I get hit with another doubt.',
                               'This is probably a dumb thing to post but... yeah, just trying to make sense of it all.',
                               'Feeling kind of lost tbh, but maybe that’s normal?',
                               'Just curious—how do people usually approach this?',
                               'Ive read a bunch of threads, but none of them really match my situation.',
                               'When did you know it was the right time to make a big change?',
                               'Woke up thinking “maybe today’s the day I figure it out” lol.',
                               'Open to ideas, I guess. Nothing’s really working right now.',
                               'Seen people do this two totally different ways—both seem valid. So what now?',
                               'Not expecting answers, just putting it out there.',
                               'Kinda wish someone had a roadmap for this stuff.',
                               'How do people even start with something like this? Feels overwhelming.',
                               'Trying to stay positive but it’s getting harder to know what to do next.',
                               'Just wondering if I’m the only one who’s been stuck in this weird limbo.'
                               
]

# %%
def convert_to_csv(full_text_dict):

    pd_df = pd.DataFrame({'premise': [], 'hypothesis': [], 'label': []})
    label_list = full_text_dict.keys()

    hypotheses = {
        "gratitude":  "This text expresses gratitude.", 
        "frustration":  "This text expresses frustration.",
        "political": "This text is political in nature.",
        "solution focsed": "This text is focused on solutions.",
        "information or news": "This text provides information or news.",
        "fear or panic": "This text expresses fear or panic.",
        "blaming": "This text contains blaming.",
        "seeking help or advice": "This text is seeking help or advice.",
        "wildfires": "This text is about wildfires.",
        "prescribed burns": "This text is about prescribed burns",
        "fire management": "This text is about fire management",
    }

    for label in full_text_dict.keys():
        current_list = full_text_dict[label]
        label_name = label 

        for current_text in current_list:
            for hypothesis in hypotheses.keys():
                premise = current_text
                hyp = hypotheses[hypothesis]

                if label == hypothesis:
                    lab = 'entailment'
                else:
                    lab = 'contradiction'

                pd_df.loc[len(pd_df)] = {
                    'premise': premise,
                    'hypothesis': hyp,
                    'label': lab
                }

    pd_csv = pd_df.to_csv("GPT_training.csv", index=False)

    return pd_csv
    
# Throws all lists into a dictionary in order to make label names easier to work with.

def convert_to_dict(full_text_list):
    full_text_dict = {
        "gratitude": full_text_list[0],
        "frustration": full_text_list[1],
        "political": full_text_list[2],
        "solution focsed": full_text_list[3],
        "information or news": full_text_list[4],
        "fear or panic": full_text_list[5],
        "blaming": full_text_list[6],
        "seeking help or advice": full_text_list[7],
        "wildfires": [],
        "prescribed burns": [],
        "fire management": []
    }

    return full_text_dict

# %%
full_list = [grateful_text, frustration_text, political_text, solution_focused_text, informative_news_focused_text, 
             fearful_or_panicked_text, blaming_text, seeking_help_or_advice_text]
list_to_dict = convert_to_dict(full_list)

# %%
convert_to_csv(list_to_dict)
